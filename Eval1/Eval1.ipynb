# %%
import matplotlib.pyplot as plt;import pandas as pd

# %%
import matplotlib as plt

# %%
import numpy as np

# %%
import pylab as pl;import csv

# %%
df=pd.read_csv("datos.csv", header=int(1))

# %%
df.head()
# Out:
#    Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0  1880 -0.87 -0.49 -0.53 -0.69 -0.40 -0.52 -0.50  0.00 -0.55 -0.68 -0.54
# 1  1881 -0.82 -0.67 -0.43 -0.33 -0.09 -1.15 -0.62 -0.32 -0.46 -0.62 -0.65
# 2  1882  0.02 -0.22 -0.18 -0.67 -0.45 -1.07 -0.79 -0.19 -0.11 -0.39 -0.49
# 3  1883 -0.77 -1.01 -0.58 -0.42 -0.46  0.29 -0.15 -0.29 -0.58 -0.67 -0.80
# 4  1884 -0.62 -0.48 -0.60 -1.00 -1.26 -0.90 -0.97  0.02 -0.46 -0.86 -0.92
#
#     Dec   J-D   D-N   DJF   MAM   JJA   SON
# 0 -0.59 -0.53   ***   *** -0.54 -0.34 -0.59
# 1 -0.21 -0.53  -.56  -.70 -0.28 -0.70 -0.58
# 2 -0.75 -0.44  -.39  -.14 -0.43 -0.68 -0.33
# 3 -0.51 -0.50  -.52  -.84 -0.49 -0.05 -0.68
# 4 -1.07 -0.76  -.71  -.54 -0.95 -0.62 -0.75

# %%
dft= df[:-1]

# %%
df_tmp = df.copy()
df1=df_tmp.drop(labels=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec','D-N','DJF','MAM','JJA','SON'], axis=1)
#df1 esta archivo incluira las columnas que se graficaran. 
df1.head()
# Out:
#    Year   J-D
# 0  1880 -0.53
# 1  1881 -0.53
# 2  1882 -0.44
# 3  1883 -0.50
# 4  1884 -0.76

# %%
from pylab import figure, show, legend, xlabel, ylabel
import numpy as np
import matplotlib.pyplot as mplt
from matplotlib import rc
y=df1[u'J-D']
x=df1[u'Year']
mplt.plot(x,y,marker='.',color='green')
mplt.plot(x,y,color='blue',label='anomalías original')
mplt.grid(True)
pl.xlabel('Years')
pl.ylabel('Temperature')
pl.title('Temperature anomaly (c) vs. Years')

# %%
y=df1[u'J-D']
x=df1[u'Year']
lowess=sm.nonparametric.lowess(y,x,frac=0.1)
plt.plot(lowess[:, 0],lowess[:, 1],'r-',label='anomalías suavizada')

# %%
plt.legend( loc='upper left', numpoints = 1 )
plt.show()

# %%
df.boxplot(['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
pl.xlabel('Meses')
pl.ylabel('Variabilidad')
pl.title('Boxplot por meses')
mplt.show()
# Out:
# /opt/anaconda/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   if __name__ == '__main__':
